# %%
print("Machine learning engineer")
# Out:
# Machine learning engineer

# %%
message = "Hello Python world!"

print(message)
# Out:
# Hello Python world!

# %%
name = "rishabh singh"
print(name.title())
# Out:
# Rishabh Singh

# %%
name = "Rishabh Singh"
print(name.lower())
print(name.upper())
# Out:
# rishabh singh
# RISHABH SINGH

# %%
first_name = "rishabh"
last_name = "singh"
full_name = f"{first_name} {last_name}"
print(full_name)
# Out:
# rishabh singh

# %%
first_name = "rishabh"
last_name = "singh"
full_name = f"{first_name} {last_name}"
message = f"Hello!, {full_name.title()}"
print(message)
# Out:
# Hello!, Rishabh Singh

# %%
print("Python")
print("\tPython")
# Out:
# Python
# 	Python

# %%
print("Languages:\nPython\nC\nJava")
# Out:
# Languages:
# Python
# C
# Java

# %%
print("Languages:\n\tPython\n\tC\n\tJava")
# Out:
# Languages:
# 	Python
# 	C
# 	Java

# %%
fav_language = "    Python    "
print(fav_language.lstrip())
print(fav_language.rstrip())
print(fav_language.strip())
# Out:
# Python
#     Python
# Python

# %%
url = "https://www.linkedin.com/feed/"
simple_url = url.removeprefix("https://")
print(simple_url)
# Out:
# www.linkedin.com/feed/

# %%
email_address = "jsgdfj@gmail.com"
user_name = email_address.removesuffix("@gmail.com")
print(user_name)
# Out:
# jsgdfj

# %%
message = "One of the Python's strengths is its diverse community"
print(message)
# Out:
# One of the Python's strengths is its diverse community

# %%
message = 'One of the Python's strengths is its diverse community'
print(message)
# Out:
#   Cell In[14], line 1
#     message = 'One of the Python's strengths is its diverse community'
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#Personal message

person_name = "Shreya"

message = f"Hello {person_name}, would you like learn some Python today?"

print(message)
# Out:
# Hello Shreya, would you like learn some Python today?

# %%
#Name Cases

person_name = "shreya"

print(f"{person_name.upper()}\n{person_name.lower()}\n{person_name.title()}")
# Out:
# SHREYA
# shreya
# Shreya

# %%
#Famous Quote

quote = "Dream, dream, dream. Dreams transform into thoughts, and thoughts result in action."

author_name = "Dr. A.P.J. Abdul Kalam"

message = f'{author_name} once said, "{quote}"'

print(message)
# Out:
# Dr. A.P.J. Abdul Kalam once said, "Dream, dream, dream. Dreams transform into thoughts, and thoughts result in action."

# %%
#Stripping Names

person_name = "    Rishabh \n\tSingh  "
print(person_name)
print(person_name.lstrip())
print(person_name.rstrip())
print(person_name.strip())
# Out:
#     Rishabh
# 	Singh
# Rishabh
# 	Singh
#     Rishabh
# 	Singh
# Rishabh
# 	Singh

# %%
#File Extenstions

filename = "python_notes.txt"
file_browser = filename.removesuffix(".txt")
print(file_browser)
# Out:
# python_notes

# %%
0.2 + 0.1
# Out:
# 0.30000000000000004

# %%
3 * 0.1
# Out:
# 0.30000000000000004

# %%
a = 10_00

# %%
a
# Out:
# 1000

# %%
print(6+2) #Addition
print(18-10) #Substraction
print(2*4) #Multiplication
print(24/3) #Division
# Out:
# 8
# 8
# 8
# 8.0

# %%
# Favorite number

fav_num = 69
print(f"My favorite number is {fav_num}") # print out my favorite number
# Out:
# My favorite number is 69

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
